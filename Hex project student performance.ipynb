# %%
import pandas as pd

# %%
student_performance = pd.read_csv ('Desktop/student_performance.csv')

# %%
student_performance
# Out:
#     student_id  gender  age  study_hours_per_week  attendance_rate  \
# 0      STU0001    Male   15                    25             63.8
# 1      STU0002  Female   15                     2             54.7
# 2      STU0003  Female   19                    10             90.5
# 3      STU0004    Male   16                    26             66.8
# 4      STU0005  Female   15                    25             73.0
# ..         ...     ...  ...                   ...              ...
# 495    STU0496  Female   19                     6             78.3
# 496    STU0497  Female   16                    27             61.1
# 497    STU0498  Female   18                    16             72.3
# 498    STU0499    Male   17                    29             91.3
# 499    STU0500    Male   15                    29             75.4
#
#     parent_education internet_access extracurricular  previous_score  \
# 0           Bachelor             Yes             Yes              41
# 1           Bachelor             Yes             Yes              83
# 2        High School             Yes              No              73
# 3        High School              No             Yes              75
# 4        High School              No             Yes              67
# ..               ...             ...             ...             ...
# 495           Master              No              No              51
# 496              PhD              No              No              47
# 497           Master              No             Yes              52
# 498              NaN             Yes              No              39
# 499      High School              No             Yes              34
#
#      final_score passed
# 0             67    Yes
# 1             28     No
# 2             49     No
# 3             70    Yes
# 4             77    Yes
# ..           ...    ...
# 495           27     No
# 496           74    Yes
# 497           61    Yes
# 498           86    Yes
# 499           74    Yes
#
# [500 rows x 11 columns]

# %%
student_performance.shape
# Out:
# (500, 11)

# %%
student_performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            500 non-null    object
#  1   gender                500 non-null    object
#  2   age                   500 non-null    int64
#  3   study_hours_per_week  500 non-null    int64
#  4   attendance_rate       500 non-null    float64
#  5   parent_education      383 non-null    object
#  6   internet_access       500 non-null    object
#  7   extracurricular       500 non-null    object
#  8   previous_score        500 non-null    int64
#  9   final_score           500 non-null    int64
#  10  passed                500 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 43.1+ KB

# %%
student_performance.head()
# Out:
#   student_id  gender  age  study_hours_per_week  attendance_rate  \
# 0    STU0001    Male   15                    25             63.8
# 1    STU0002  Female   15                     2             54.7
# 2    STU0003  Female   19                    10             90.5
# 3    STU0004    Male   16                    26             66.8
# 4    STU0005  Female   15                    25             73.0
#
#   parent_education internet_access extracurricular  previous_score  \
# 0         Bachelor             Yes             Yes              41
# 1         Bachelor             Yes             Yes              83
# 2      High School             Yes              No              73
# 3      High School              No             Yes              75
# 4      High School              No             Yes              67
#
#    final_score passed
# 0           67    Yes
# 1           28     No
# 2           49     No
# 3           70    Yes
# 4           77    Yes

# %%
student_performance.tail()
# Out:
#     student_id  gender  age  study_hours_per_week  attendance_rate  \
# 495    STU0496  Female   19                     6             78.3
# 496    STU0497  Female   16                    27             61.1
# 497    STU0498  Female   18                    16             72.3
# 498    STU0499    Male   17                    29             91.3
# 499    STU0500    Male   15                    29             75.4
#
#     parent_education internet_access extracurricular  previous_score  \
# 495           Master              No              No              51
# 496              PhD              No              No              47
# 497           Master              No             Yes              52
# 498              NaN             Yes              No              39
# 499      High School              No             Yes              34
#
#      final_score passed
# 495           27     No
# 496           74    Yes
# 497           61    Yes
# 498           86    Yes
# 499           74    Yes

# %%
# Check missing values
student_performance.isnull().sum()
# Out:
# student_id                0
# gender                    0
# age                       0
# study_hours_per_week      0
# attendance_rate           0
# parent_education        117
# internet_access           0
# extracurricular           0
# previous_score            0
# final_score               0
# passed                    0
# dtype: int64

# %%
student_performance.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Numerical
student_performance.fillna(student_performance.median(numeric_only=True), inplace=True)

# %%
student_performance.describe()
student_performance.describe(include='object')
# Out:
#        student_id  gender parent_education internet_access extracurricular  \
# count         500     500              500             500             500
# unique        500       2                4               2               2
# top       STU0001  Female           Master             Yes              No
# freq            1     273              217             254             253
#
#        passed
# count     500
# unique      2
# top       Yes
# freq      323

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.histplot(student_performance['final_score'])
plt.title("Distribution of Final Scores")
plt.show()

# %%
sns.boxplot(x=student_performance['study_hours_per_week'])
plt.show()

# %%
sns.countplot(x='gender', data=student_performance)
plt.show()

# %%
sns.countplot(x='passed', data=student_performance)
plt.show()

# %%
sns.scatterplot(x='study_hours_per_week', y='final_score', data=student_performance)
plt.show()

# %%
sns.scatterplot(x='attendance_rate', y='final_score', data=student_performance)
plt.show()

# %%
sns.boxplot(x='parent_education', y='final_score', data=student_performance)
plt.show()

# %%
sns.boxplot(x='internet_access', y='final_score', data=student_performance)
plt.show()

# %%
corr = student_performance.corr(numeric_only=True)

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
student_performance['performance_level'] = pd.cut(student_performance['final_score'],
                                bins=[0,50,75,100],
                                labels=['Low','Average','High'])

# %%
sns.pairplot(student_performance)

# %%
sns.relplot(x= 'final_score', y='study_hours_per_week', hue='gender', data=student_performance)

# %%
sns.relplot(x= 'final_score', y='study_hours_per_week', hue='internet_access', data=student_performance)
